# %% [markdown]
# ### Topics to be covered

# %% [markdown]
# 1. Random Sample Imputation<br>
# here we select random number to fill the missing value but the random number are from the data which are availabe in that column so its will be in a boundry of the data availabe in the columns<br>
# 2. Can be used in both numberic and categorical columns

# %% [markdown]
# Covariance with other columns will disturbe<br>
# Memory heavy for deployment as we need to stoer the original training set to ectract value from and replace the NA in coming observation<br>
# Well suited for linear models as it does not distort the distrubution ,regardless of the % of NA

# %% [markdown]
# ### Missing Indicator

# %% [markdown]
# for every column having an missing value we create an new columns and the values in that new column is true/false, True if the vlaue is missing or else false
